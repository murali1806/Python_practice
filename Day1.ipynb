# %%
print("murali")
# Out:
# murali

# %%
x=5
if x>=5:
    print("less than 5")
# Out:
# less than 5

# %%
## used to comment these won't get executed 
"""x=10
y=10
print (x)"""
# Out:
# 'x=10\ny=10\nprint (x)'

# %%
x=True ##bollean
y=10 ## integer
z='hello' ##string '10' also string 
a=1.3 ##float
print( x, type(x))
print( y, type(y))
print( z, type(z))
print( a, type(a))
# Out:
# True <class 'bool'>
# 10 <class 'int'>
# hello <class 'str'>
# 1.3 <class 'float'>

# %%
def order(x):
    food= x
    print("your order is:",food)

order("apple")
# Out:
# your order is: apple

# %%
##local, enclosing, global, built-in variables
##disc can be used in an inner function this is enclosing
y=5 ##global variable can  be used anywhere
def card():
    enclosing=10 ##enclosing variable can be used in inner function
    def checkout():
            disc=10 ##local varaible 
            print(y) ##Print in built in varaible 
            print(disc)
            print(enclosing)
    checkout()
    print(y)
card()
# Out:
# 5
# 10
# 10
# 5

# %%
##TYPE CASTING 
x='10'
y='1'
z='Apple' ##this cannot be converted to an integer
w="1.5"
f=float(w) ## int(w) will get error because 1.5 is not integer it is float
print(f,type(f))
a=int(x) ## change the data from string to integer
print(type(x))
print(type(a))
print(x+y)  ##concatenated 
print(a+int(y)) ## added after changing both to integer
# Out:
# 1.5 <class 'float'>
# <class 'str'>
# <class 'int'>
# 101
# 11

# %%
##operator and expression
#+-%*/ AND OR NOT 
# # arithmetic operator 
a=10
b=5
print("add",a+b)
print("sub",a-b)
print("modula",a%b)
print("divide",a/b)
print("mulitple",a*b)
print("exponent divide",a//b) ## exponent 10/5 =2 not decimal values like 2.3 it will round to 2
print(b,"time mulitple",a**b) ## 10*10*10*10*10  floor division
a-=b  ## add or subtract the value and store it again in a
print("output store again in a:",a)
##comaprsion 
x=10
y=10
print(x==y)
print(x!=y)
print(x<y)
print(x>y)

##logical 
print("\n") ## new line character 
g=True
v=True
print( g and v)
print(g or v)
print(not v) ##not means "opposite of the truth value." It doesn't always mean False; it flips True to False and False to True
# Out:
# add 15
# sub 5
# modula 0
# divide 2.0
# mulitple 50
# exponent divide 2
# 5 time mulitple 100000
# output store again in a: 5
# True
# False
# False
# False
#
#
# True
# True
# False

# %%
# # condition clause using comparison and arithmetic operators 

amount=200
tax= amount*0.18
total = amount+tax  ## arithmetic operator
if total>100: ## conditional operator 
    discount= total*.10
    total -= discount 
print (total)

if total >100 and total <200: ## logical operator 
    print("amount is ",total)
else:
    print (total, "amount is not in range")
# Out:
# 212.4
# 212.4 amount is not in range

# %%
## input from during runtime  
a= input("enter a")
b= input("enter b") ## input will be stored as a string if we get any input
c= int(input("enter c"))
d= int(input("enter d"))## string is typecaste from string to integer 
print(a+b) ## when we give + it got concatenate 
print(c+d)
# Out:
# enter a 1
# enter b 2
# enter c 1
# enter d 2
# 12
# 3

# %%
##input while triggering the job
## Save this in a separate Python file and give "python userinput.py Murali" in the terminal
import sys 
name = sys.argv[1]


##format the name 
email= name.lower().replace(" ",".")+"@gmail.com"

print("\n--profile--")
print("full name:",name)
print("email:",email)

##ouput
##--profile--
##full name: Murali
##email: murali@gmail.com
# # Other scenarios to try in the terminal
##lastname=sys.argv[2] ## if 2 sys defined, we need to give 2 inputs in the terminal, else query fails then give this "python userinput.py Murali km" 

##input murali 1 2 3
##name = sys.argv[1]  
##print(name) --> ['murali', '1', '2', '3']
##if you need in a single statement
##name =" ".join(sys.argv[1:])  ##join used to remove the list
##print(name) --> [murali 1 2 3]
# Out:
# --profile--
# full name: -f
# email: -f@gmail.com

# %%
##string handling and manipulation

name = "MuraLi"
mobile="9994578697"
masked =mobile[:2] +"******"+mobile[-2:]
print(masked)
print(f"My name is {name.upper()}, working in IT") ## f-string is used, we can define the variable anywhere inside {}
print(name.lower())
print(name.upper())
print(name.capitalize())

##input 
details="i am murali"
work="WORKING in it"
formatted=f"{details.title()} , {work.title()}" ##title will change the first letter in all the word
print(formatted)

location="Bangalore"
fix_location=location.replace("Bangalore","Chennai") ## repalce the word
print(fix_location)

message= "your otp is: 123456 . don't share"
id=message.split(":")[1].split(".")[0] ##In split [0] means before : values, [1] after : values 
print(len(id))
print(id.strip()) ##strip means remove space in starting and end

##search FREE100 in the word
promo="this your coupon FREE100, get 100 off on purchase"
if "FREE100" in promo:  ## search word using in function inside if clause.
    print ("offer applied")
# Find where this coupon is present
print("position is :",promo.find("FREE100")) ## find used to get the starting letter

name = "muralidharan mariayappan"
intial = [word[0].upper() for word in name.split()]
print(intial)
intial = "".join([word[0].upper() for word in name.split()])##join removes the list
print(intial)

word="i am going to native will retun next week"
word_count=len(word.split())
print(word_count)
# Out:
# 99******97
# My name is MURALI, working in IT
# murali
# MURALI
# Murali
# I Am Murali , Working In It
# Chennai
# 8
# 123456
# offer applied
# position is : 17
# ['M', 'M']
# MM
# 9

# %%
def add(a,b):
    c=a+b
    return a+b

print(add(1,1))
# Out:
# 2
# 2
