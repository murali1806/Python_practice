# %% [markdown]
#                 Ops concepts
# class contains methods for operations on numbers
# class means that it is a blueprint for creating objects that can perform various mathematical operations. The methods within the class can be used to add, subtract, multiply, and divide numbers, among other operations.
#
# if we 10 have functions will all comes under one category, that one category is defined as class for easy understanding.
# example :
# School is class inside that below are methods:
# student list is one method(nothing but function)
# teacher list is one method(nothing but function)
# exam is one method(nothing but function)
# course is one method(nothing but function)

# %%
class student:  ##class definition
    def say_hello(self): ##method of class, self is a reference to the current instance of the class
        print("Hello, I am a student.")

s1=student() #calling the class to create an object S1 of the class
s1.say_hello() #s1.say_hello(s1) ##calling the method of the class using the object S1


##procedure 
def team(): ## if defined outside the class, it is a function
    print("We are a team of students.")

team()
# Out:
# Hello, I am a student.
# We are a team of students.

# %%
##constructor is a special method that is called when an object is created. It is used to initialize the attributes of the class. 
#The __init__ method is called automatically when an object is created.
#if same attributes used in mulitiple methods use constructor
class student:
    def __init__(self, name, age, grade): ##constructor method, it is called when an object is created. It is used to initialize the attributes of the class.
        self.name = name ##variables
        self.age = age
        self.grade = grade

    def get_grade(self): ##method get the fields from above contructor
        print(f"{self.name} is in grade {self.grade}")

    def get_age(self): #methods
        print(f"{self.name} age is {self.age}")

#creating mulitple objects of the class student with different attributes
#create memory for each object and store the attributes in it
S1=student("murali",26, "A") #creating an object S1 of the class student
S2=student("sai", 25, "B") #creating an object S2 of the class student
S3=student("kumar", 27, "C") #creating an object S3 of the class student


S1.get_grade() #calling the method get_grade() of the class student using the object S1
S2.get_grade() #calling the method get_grade() of the class student using the object S2
S3.get_grade() #calling the method get_grade() of the class student using the object

S1.get_age() 
S2.get_age() 
S3.get_age() #calling the method get_age() of the class student using the object S1, S2, S3
# Out:
# murali is in grade A
# sai is in grade B
# kumar is in grade C
# murali age is 26
# sai age is 25
# kumar age is 27

# %%
##without constructor, we can create an object of the class student and then set the attributes using the methods of the class. But with constructor, we can set the attributes while creating the object of the class student.

class math:
    def add(self,a,b):
        return a+b
    def sub(self,a,b):
        return a-b
    def mul(self,a,b):
        return a*b
    def div(self,a,b):
        return a/b
calculator=math() #creating an object calculator of the class math
print("addition:",calculator.add(1,3)) #calling the method add() of the class math using the object calculator
print("subtraction:",calculator.sub(1,3)) #calling the method sub() of the class math using the object calculator
print("mulitply:",calculator.mul(1,3)) #calling the method mul() of the class math using the object calculator
print("division:",calculator.div(1,3)) #calling the method div() of the class math using the object calculator
# Out:
# addition: 4
# subtraction: -2
# mulitply: 3
# division: 0.3333333333333333

# %%
#with constructor example in data 
class Database:

    def __init__(self, server, database, username, password):
        self.server = server
        self.database = database
        self.username = username
        self.password = password

    def connect(self):
        print(f"Connecting to {self.server}")

    def read(self):
        print("Reading data")

    def write(self):
        print("Writing data")

db1 = Database("DEV","Snowflake","murali","password")
db2= Database("PROD","Snowflake","murali","password")

db1.connect()
db1.read()
db1.write()

db2.connect()
db2.read()
db2.write()
# Out:
# Connecting to DEV
# Reading data
# Writing data
# Connecting to PROD
# Reading data
# Writing data

# %% [markdown]
#             Inheritance
# Reuse the code
# create child class from parent class

# %%
#single level inheritance is the first type.
class dad1: #parent
    def house(self):
        print("my dad house")

class son(dad1): #child #single level
    def factory(self):
        print("my factory")

net=son()  ## net object is created only for son, but in method son is already linked to dad 
net.factory() # we can access son methods in net object 
net.house()  # And we can access dad methods in net object
# Out:
# my factory
# my dad house

# %%
#multilevel inheritance
class grandfather: #first parent #multilevel
    def car(self):
        print("my grandfather car")

class dad1(grandfather): #parent #multilevel
    def house(self):
        print("my dad house")

class son(dad1): #child
    def factory(self):
        print("my factory")

family=son() ##object for last class
family.car()
family.house()
family.factory()
# Out:
# my grandfather car
# my dad house
# my factory

# %%
#hierarchy inheritance

class dad1: #parent
    def house(self):
        print("my dad house")

class son(dad1): #child #hierarchy
    def factory(self):
        print("my factory")

class son2(dad1): #child  #hierarchy
    def market(self):
        print("my market")

# for hierarchy we need to create seperate objects for each class which use same parent class

me=son()
me.house()
me.factory()
print ("seperater object for class which use same parent class")

brother=son2() ##create seperate object which use same parent class 
brother.house()
brother.market()
# Out:
# my dad house
# my factory
# seperater object for class which use same parent class
# my dad house
# my market

# %%
#Mulitple inheritance

class dad1: #parent
    def house(self):
        print("my dad house")

class mom: #parent
    def shop(self):
        print("my mom shop")

# for mulitple inheritance we need link both parent class to access those different methods.
class daughter(dad1,mom): #child ##mulitple inheritance 
    def market(self):
        print("my market")

me=daughter()
me.house()
me.shop()
# Out:
# my dad house
# my mom shop

# %%
#hybrid inheritance if we are using different type of inheritance in single code

# %% [markdown]
# Real time example

# %% [markdown]
# Reference: file name = import_check.py
#
# class dad: #parent
#     def house(self):
#         print("my dad house")
# a=dad()
# a.house()

# %%
##this is also called as polymorphisam 
from import_check import dad  ##this part used to import the dad method from another python files class

class son(dad): #child
    def factory(self):
        print("my factory")

i=son()
i.house()
i.factory()
# Out:
# my dad house
# my factory

# %%
## In app1 change the data from one to two.
## you shouldn't directly overwrite Version1, need to create child and in that create method as version2, this is called inheritance.

class app1:
    def v1(self):
        print("one")
class app1_1(app1): 
    def v2(self):
        print("two")

    def v1(self):  ##if you need to update the exisitng logic in version 1, create same method V1 in last child method. so it will return last child method value.
        print("three")

live1=app1_1() ## object need to be created only for last child class
live1.v1()  ## V1 will fetched from last child not from parent if same method name becuase it will override the parent 
live1.v2()  

##if you no need of v2 changes becuase of more bug so revert back to V1, then just change the object don't remove the app1_1(V2) class 
#just for understanding changed live1 to live
print("if no need of v2 changes becuase of more bug so revert back to V1")
live=app1()
live.v1()
#live.v2() ## jsut remove this method call
# Out:
# three
# two
# if no need of v2 changes becuase of more bug so revert back to V1
# one

# %% [markdown]
#         Polymorphism

# %%
#Polymorphism means the same method name can behave differently depending on the object that calls it.
class app1:
    def v1(self):
        print("one")
class app1_1(app1): 
    def v2(self):
        print("two")

    def v1(self):  ##overriding the app1 v1 logic 
        print("three")

live1=app1_1()
live1.v1()   ## V1 will fetched from last child not from parent if same method name becuase it will override the parent 
live1.v2()
# Out:
# three
# two

# %% [markdown]
# Abstracion
# Abstraction in Python means hiding the implementation details and showing only the essential functionality to the user.
# Real-world example 🚗
# Think about driving a car.
# You use the steering wheel, accelerator, and brake.
# You don't need to know how the engine, gearbox, or fuel injection system works.
#
# The car hides the complex implementation and only exposes what you need
#
# ###
# Abstract means which all methods used in parent need to defined in child else job will through error.

# %%
from abc import ABC, abstractmethod 

class feature(ABC): ##ABC is the abstract syntax
    @abstractmethod
    def login(self):
        pass
    @abstractmethod ## once @abstractmethod is defined these methods need to mandatoryly used in child class
    def logout(self):
        pass
   ##@abstractmethod commented becuase this method is not defined in child
    #abstract can be defined or not defined in ABC imported 
    def checkout(self):
        pass

class app(feature):
    def login(self):
        print("logged in")
    def logout(self):
        print("logged out")
    
user=app()
user.login()
user.logout()

##using operator we should not call the abstract class
# Out:
# logged in
# logged out

# %% [markdown]
# Access specifer & Access modifier
# For variable and method giving access using this.

# %%
## access specifer for varaible 
class parent():
    def __init__(self):
        self.public_id=123    ##public
        self._protect_name="murali"  ## _ one underscore means protected
        self.__private_number="99452654" ##__ double underscore means private

class child(parent):
    def id(self):
        print("public id:",self.public_id)
        print("protect name",self._protect_name)
        try:
            print("private_no:",self.__private_number)  ## if you try to access private will through error
        except AttributeError:
            print("Private is not accessible ")

        ##private also can abe accessed using this but it is not ethical, this is called manhandaling 
        print("private number", self._parent__private_number) ## _parent is defined during call, we can access the private variable also.

class relative(): ##parent is not linked
       def id(self, obj):
        print("public id:",obj.public_id)
        print("protect name",obj._protect_name)
        try:
            print("private_no:",obj.__private_number)  ## if you try to access private will through error
        except AttributeError:
            print("Private is not accessible ")
p=parent()
s=child()
s.id()

r=relative()
r.id(p)  ##but here parent is linked using p operator in r operator, if not will get error.
# Out:
# public id: 123
# protect name murali
# Private is not accessible
# private number 99452654
# public id: 123
# protect name murali
# Private is not accessible

# %%
## access specifer for method 

class parent():
    def public(self):
       print("public method")
    def _protect(self):     ## _ means protected method
       print("protected method")
    def __private(self):    ## __ means private method 
       print("private method")

    def call(self):  ##using this method we can call other methods in same class
        self.public()
        self._protect()
        self.__private()

class child(parent):
    def id(self):
        self.public()
        self._protect()
        try:
            self.__private()  ## if you try to access private will through error
        except AttributeError:
            print("Private is not accessible ")

        ##private also can abe accessed using this but it is not ethical, this is called manhandaling 
        self._parent__private() ## _parent is defined during call, we can access the private variable also.

class relative(): ##parent is not linked
    def id(self, obj):    
        print("\n")
        obj.public()
        obj._protect()
        try:
            obj.__private()  ## if you try to access private will through error
        except AttributeError:
            print("Private is not accessible ")
p=parent()
p.call()
s=child()
s.id()

r=relative()
r.id(p)
# Out:
# public method
# protected method
# private method
# public method
# protected method
# Private is not accessible
# private method
#
#
# public method
# protected method
# Private is not accessible

# %% [markdown]
# Encapsulation
#
# variable and method kept in single class and it is protected from other class and methods
